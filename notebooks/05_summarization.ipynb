# %% [markdown]
# # 05 — Summarization for Research Notes
# Condense long pages into short briefs for faster strategy.

# %%
from transformers import pipeline
summarizer = pipeline('summarization', model='sshleifer/distilbart-cnn-12-6')
text = 'Running shoes have varied cushioning systems ...' * 50
summarizer(text, max_new_tokens=128)
